# %%
#https://www.kaggle.com/melihkanbay/police

# %%
from Data_Pipeline import data_analisis_pipeline as dap

# %%
df = dap()
# Out:
# Please enter the url where your desired csv is: https://www.kaggle.com/melihkanbay/police
# Default enconding is ISO-8859-1, do you prefer another one? Please type it.
#                        0
# stop_date             0%
# stop_time             0%
# county_name         100%
# driver_gender         6%
# driver_age_raw        6%
# driver_age            6%
# driver_race           6%
# violation_raw         6%
# violation             6%
# search_conducted      0%
# search_type          97%
# stop_outcome          6%
# is_arrested           6%
# stop_duration         6%
# drugs_related_stop    0%
# Do you want to remove duplicates,empty rows/columns, and irrelevant stadistical columns? y/ny
# Who must be the maximum nan values in a row? Please insert a value between 0-15: 0
# What is the maximum % of nan in a column to be stadistical relevant? Insert a value between 0-100, (default is 95%): 90
# 4 columns dropped
# 479 rows dropped
# The new shape is 91262 rows and 11 columns
# ...

# %%
df.info()
df.head(
)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 91262 entries, 0 to 91740
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   stop_time       91262 non-null  object
#  1   driver_gender   86137 non-null  object
#  2   driver_age_raw  91262 non-null  float64
#  3   driver_age      91262 non-null  float64
#  4   driver_race     86139 non-null  object
#  5   violation_raw   86139 non-null  object
#  6   violation       86139 non-null  object
#  7   stop_outcome    86139 non-null  object
#  8   is_arrested     91262 non-null  object
#  9   stop_duration   86139 non-null  object
#  10  year            91262 non-null  int64
#  11  month           91262 non-null  int64
#  12  day             91262 non-null  int64
# dtypes: float64(2), int64(3), object(8)
# memory usage: 11.8+ MB
#   stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# ...

# %%
a = list(dict(df["driver_gender"].value_counts()).keys())
list(a)
# Out:
# ['m', 'f']
