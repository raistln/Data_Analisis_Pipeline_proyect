# %%
from import_load_kaggle import download_import_kaggle
from first_view import first_view
from data_wrangling import data_wrangling
from pdf_report import pdf_report

# %%
def main():
    df = download_import_kaggle()
    df = first_view(df)
    df = data_wrangling(df)
    pdf_report(df)
    
if __name__ == "__main__":
    main()
# Out:
# Please enter the url where your desired csv is:
# https://www.kaggle.com/teajay/global-shark-attacks
# Default enconding is ISO-8859-1, do you prefer another one? Please type it.
#                            0
# case number              66%
# date                     76%
# year                     76%
# type                     76%
# country                  76%
# area                     77%
# location                 78%
# activity                 78%
# name                     76%
# sex                      78%
# age                      87%
# injury                   76%
# fatal (y/n)              78%
# time                     89%
# species                  87%
# investigator or source   76%
# pdf                      76%
# href formula             76%
# href                     76%
# case number.1            76%
# case number.2            76%
# original order           75%
# unnamed: 22             100%
# unnamed: 23             100%
# Do you want to remove duplicates,empty rows/columns, and irrelevant stadistical columns? y/n:
# y
# How many non-nan requires in a row? Please insert a value between 0-24:
# 0
# What is the maximum % of nan in a column to be stadistical relevant? Insert a value between 0-100, (default is 95%):
# 70
# 2 columns dropped
# 19411 rows dropped
# The new shape is 6312 rows and 22 columns
# Do you want to use all the df(yes) or just a part(n)? y/n:
# y
#
#
#
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6312 entries, 0 to 25722
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   case number             6310 non-null   object
#  1   date                    6302 non-null   object
#  2   year                    6300 non-null   object
#  3   type                    6298 non-null   object
#  4   country                 6252 non-null   object
#  5   area                    5847 non-null   object
#  6   location                5762 non-null   object
#  7   activity                5758 non-null   object
#  8   name                    6092 non-null   object
#  9   sex                     5737 non-null   object
#  10  age                     3471 non-null   object
#  11  injury                  6274 non-null   object
#  12  fatal (y/n)             5763 non-null   object
#  13  time                    2948 non-null   object
#  14  species                 3464 non-null   object
#  15  investigator or source  6285 non-null   object
#  16  pdf                     6302 non-null   object
#  17  href formula            6301 non-null   object
#  18  href                    6302 non-null   object
#  19  case number.1           6302 non-null   object
#  20  case number.2           6302 non-null   object
#  21  original order          6309 non-null   object
# dtypes: object(22)
# memory usage: 1.1+ MB
# None
# Do you want to change a column to a numerical type? y/n:
# y
# Do you want it to make it automatic(y) or by yourself(n)? y/n:
# y
# For the column "year", do you want to fill the nan with median, mean or nan? Write one of them.
# nan
# For the column "original order", do you want to fill the nan with median, mean or nan? Write one of them.
# nan
# Do you want to change a column to a categorical type? y/n:
# y
# The columns that could be categorical are ['year', 'type', 'country', 'sex', 'age', 'fatal (y/n)'], do you want to change all(y) or do it manually(n)? y/n:
# y
# 2015.0    143
# 2017.0    136
# 2016.0    130
# 2011.0    128
# 2014.0    127
#          ...
# 1804.0      1
# 1802.0      1
# 1801.0      1
# 1800.0      1
# 1788.0      1
# Name: year, Length: 250, dtype: int64
# ------------------------------------------
# For the column year.
# If the column isn´t categorical left blank the next cuestion.
# Do you want to make a pattern? y/n: n
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-74992a9db4dc> in <module>
#       6
#       7 if __name__ == "__main__":
# ----> 8     main()
#
# <ipython-input-5-74992a9db4dc> in main()
#       2     df = download_import_kaggle()
#       3     df = first_view(df)
# ----> 4     df = data_wrangling(df)
#       5     pdf_report(df)
#       6
#
# ~/Python y Machine Learning/Portfolio/Data_Analisis_Pipeline_proyect/src/data_wrangling.py in data_wrangling(df)
#     230         if cate == "y":
#     231             for col in prob_cat:
# --> 232                 df = transform_cat(df=df, col=col)
#     233         if cate == "n":
#     234             probs = input("Insert the columns you want to change to categorical:\n")
#
# ~/Python y Machine Learning/Portfolio/Data_Analisis_Pipeline_proyect/src/data_wrangling.py in transform_cat(df, col)
#      84         df = stand_categorical(col, pattern)
#      85     elif trans_cat == "n":
# ---> 86         df = stand_categorical(col, pattern)
#      87
#      88     return df
#
# ~/Python y Machine Learning/Portfolio/Data_Analisis_Pipeline_proyect/src/data_wrangling.py in stand_categorical(col, pattern, other)
#     123
#     124 def stand_categorical(col, pattern, other= None):
# --> 125     df[col] = df[col].astype("category")
#     126
#     127     try:
#
# NameError: name 'df' is not defined
